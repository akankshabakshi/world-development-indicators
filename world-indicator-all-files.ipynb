# %%
#importing libraries
import pandas as pd
import sqlite3

# %%
#insert path
path = '/Users/akankshabakshi/world-indicators.sqlite'

# %%
#build connection
conn = sqlite3.connect(path)

# %%
#all tables query
query = "select * from sqlite_master where type = 'table';"

# %%
#data frame for world indicators
world_indicators = pd.read_sql_query(query, conn)

# %%
#viewing all tables rows and columns
world_indicators
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table       Country       Country         2
# 1  table  CountryNotes  CountryNotes       186
# 2  table        Series        Series       948
# 3  table    Indicators    Indicators      4448
# 4  table   SeriesNotes   SeriesNotes   1317550
# 5  table     Footnotes     Footnotes   1317587
#
#                                                  sql
# 0  CREATE TABLE Country (\n    CountryCode TEXT,\...
# 1  CREATE TABLE CountryNotes (\n    Countrycode T...
# 2  CREATE TABLE Series (\n    SeriesCode TEXT,\n ...
# 3  CREATE TABLE Indicators (\n    CountryName TEX...
# 4  CREATE TABLE SeriesNotes (\n    Seriescode TEX...
# 5  CREATE TABLE Footnotes (\n    Countrycode TEXT...

# %%
#query for country table
country = pd.read_sql_query('select * from country', conn)

# %%
#view country table
country
# Out:
#     CountryCode           ShortName           TableName  \
# 0           AFG         Afghanistan         Afghanistan
# 1           ALB             Albania             Albania
# 2           DZA             Algeria             Algeria
# 3           ASM      American Samoa      American Samoa
# 4           ADO             Andorra             Andorra
# ..          ...                 ...                 ...
# 242         WBG  West Bank and Gaza  West Bank and Gaza
# 243         WLD               World               World
# 244         YEM               Yemen         Yemen, Rep.
# 245         ZMB              Zambia              Zambia
# 246         ZWE            Zimbabwe            Zimbabwe
#
#                                     LongName Alpha2Code        CurrencyUnit  \
# 0               Islamic State of Afghanistan         AF      Afghan afghani
# 1                        Republic of Albania         AL        Albanian lek
# ...

# %%
#view first 5 records of the country table
country.head(5)
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
#
#                        Region           IncomeGroup Wb2Code  ...  \
# 0                  South Asia            Low income      AF  ...
# ...

# %%
#view country table columns
country.columns
# Out:
# Index(['CountryCode', 'ShortName', 'TableName', 'LongName', 'Alpha2Code',
#        'CurrencyUnit', 'SpecialNotes', 'Region', 'IncomeGroup', 'Wb2Code',
#        'NationalAccountsBaseYear', 'NationalAccountsReferenceYear',
#        'SnaPriceValuation', 'LendingCategory', 'OtherGroups',
#        'SystemOfNationalAccounts', 'AlternativeConversionFactor',
#        'PppSurveyYear', 'BalanceOfPaymentsManualInUse',
#        'ExternalDebtReportingStatus', 'SystemOfTrade',
#        'GovernmentAccountingConcept', 'ImfDataDisseminationStandard',
#        'LatestPopulationCensus', 'LatestHouseholdSurvey',
#        'SourceOfMostRecentIncomeAndExpenditureData',
#        'VitalRegistrationComplete', 'LatestAgriculturalCensus',
#        'LatestIndustrialData', 'LatestTradeData', 'LatestWaterWithdrawalData'],
#       dtype='object')

# %%
#view all tables of the world indicators dataset
world_indicators
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table       Country       Country         2
# 1  table  CountryNotes  CountryNotes       186
# 2  table        Series        Series       948
# 3  table    Indicators    Indicators      4448
# 4  table   SeriesNotes   SeriesNotes   1317550
# 5  table     Footnotes     Footnotes   1317587
#
#                                                  sql
# 0  CREATE TABLE Country (\n    CountryCode TEXT,\...
# 1  CREATE TABLE CountryNotes (\n    Countrycode T...
# 2  CREATE TABLE Series (\n    SeriesCode TEXT,\n ...
# 3  CREATE TABLE Indicators (\n    CountryName TEX...
# 4  CREATE TABLE SeriesNotes (\n    Seriescode TEX...
# 5  CREATE TABLE Footnotes (\n    Countrycode TEXT...

# %%
#query of country notes table 
country_notes = pd.read_sql_query('select * from countrynotes', conn)

# %%
#As this is a huge dataset, we should view only first 5 records of the country notes table
country_notes.head(5)
# Out:
#   Countrycode         Seriescode  \
# 0         ABW  EG.EGY.PRIM.PP.KD
# 1         ABW     EG.ELC.RNEW.ZS
# 2         ABW     EG.FEC.RNEW.ZS
# 3         ABW        SM.POP.NETM
# 4         ABW        SM.POP.TOTL
#
#                                          Description
# 0  Sources: Estimated based on UN Energy Statisti...
# 1               Sources: UN Energy Statistics (2014)
# 2               Sources: UN Energy Statistics (2014)
# 3  Data sources : United Nations World Population...
# 4  Estimates are derived from data on foreign-bor...

# %%
#query for series table
series = pd.read_sql_query('select * from series', conn)

# %%
#view series table
series
# Out:
#                 SeriesCode                                              Topic  \
# 0           BN.KLT.DINV.CD  Economic Policy & Debt: Balance of payments: C...
# 1     BX.KLT.DINV.WD.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 2        BX.KLT.DINV.CD.WD  Economic Policy & Debt: Balance of payments: C...
# 3        BM.KLT.DINV.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 4           BN.TRF.KOGT.CD  Economic Policy & Debt: Balance of payments: C...
# ...                    ...                                                ...
# 1340  SL.UEM.1524.FE.NE.ZS            Social Protection & Labor: Unemployment
# 1341     SL.UEM.1524.MA.ZS            Social Protection & Labor: Unemployment
# 1342  SL.UEM.1524.MA.NE.ZS            Social Protection & Labor: Unemployment
# 1343        SL.UEM.1524.ZS            Social Protection & Labor: Unemployment
# 1344     SL.UEM.1524.NE.ZS            Social Protection & Labor: Unemployment
#
# ...

# %%
#As the columns are a lot of the series table, 
series.columns
# Out:
# Index(['SeriesCode', 'Topic', 'IndicatorName', 'ShortDefinition',
#        'LongDefinition', 'UnitOfMeasure', 'Periodicity', 'BasePeriod',
#        'OtherNotes', 'AggregationMethod', 'LimitationsAndExceptions',
#        'NotesFromOriginalSource', 'GeneralComments', 'Source',
#        'StatisticalConceptAndMethodology', 'DevelopmentRelevance',
#        'RelatedSourceLinks', 'OtherWebLinks', 'RelatedIndicators',
#        'LicenseType'],
#       dtype='object')

# %%
#view all tables in world indicator dataset
world_indicators
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table       Country       Country         2
# 1  table  CountryNotes  CountryNotes       186
# 2  table        Series        Series       948
# 3  table    Indicators    Indicators      4448
# 4  table   SeriesNotes   SeriesNotes   1317550
# 5  table     Footnotes     Footnotes   1317587
#
#                                                  sql
# 0  CREATE TABLE Country (\n    CountryCode TEXT,\...
# 1  CREATE TABLE CountryNotes (\n    Countrycode T...
# 2  CREATE TABLE Series (\n    SeriesCode TEXT,\n ...
# 3  CREATE TABLE Indicators (\n    CountryName TEX...
# 4  CREATE TABLE SeriesNotes (\n    Seriescode TEX...
# 5  CREATE TABLE Footnotes (\n    Countrycode TEXT...

# %%
#query of indicators table
indicators = pd.read_sql_query('select * from indicators', conn)

# %%
#view records of indicators table
indicators
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# ...             ...         ...
# 5656453    Zimbabwe         ZWE
# 5656454    Zimbabwe         ZWE
# 5656455    Zimbabwe         ZWE
# 5656456    Zimbabwe         ZWE
# 5656457    Zimbabwe         ZWE
#
#                                              IndicatorName      IndicatorCode  \
# 0        Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1        Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2        Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3        Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4              Arms exports (SIPRI trend indicator values)     MS.MIL.XPRT.KD
# ...                                                    ...                ...
# ...

# %%
#query for series notes table
series_notes = pd.read_sql_query('select * from seriesnotes', conn)

# %%
#view series_notes table records
series_notes
# Out:
#             Seriescode    Year  \
# 0          SP.ADO.TFRT  YR1960
# 1       SP.DYN.AMRT.FE  YR1960
# 2       SP.DYN.AMRT.MA  YR1960
# 3    SP.DYN.TO65.FE.ZS  YR1960
# 4    SP.DYN.TO65.MA.ZS  YR1960
# ..                 ...     ...
# 364  NY.ADJ.SVNG.GN.ZS  YR2013
# 365        SM.POP.REFG  YR2014
# 366     SM.POP.REFG.OR  YR2014
# 367        SP.ADO.TFRT  YR2014
# 368     DT.DOD.PVLX.CD  YR2014
#
#                                            Description
# 0           Interpolated using data for 1957 and 1962.
# 1    Interpolated using data for 1957 and 1962, if ...
# 2    Interpolated using data for 1957 and 1962, if ...
# 3           Interpolated using data for 1957 and 1962.
# 4           Interpolated using data for 1957 and 1962.
# ..                                                 ...
# 364  Pollution damage data are for 2010, the most r...
# 365    2014 data are provisional and subject to change
# 366   2014 data are provisional and subject to change.
# ...

# %%
#view all tables of world indicator dataset
world_indicators
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table       Country       Country         2
# 1  table  CountryNotes  CountryNotes       186
# 2  table        Series        Series       948
# 3  table    Indicators    Indicators      4448
# 4  table   SeriesNotes   SeriesNotes   1317550
# 5  table     Footnotes     Footnotes   1317587
#
#                                                  sql
# 0  CREATE TABLE Country (\n    CountryCode TEXT,\...
# 1  CREATE TABLE CountryNotes (\n    Countrycode T...
# 2  CREATE TABLE Series (\n    SeriesCode TEXT,\n ...
# 3  CREATE TABLE Indicators (\n    CountryName TEX...
# 4  CREATE TABLE SeriesNotes (\n    Seriescode TEX...
# 5  CREATE TABLE Footnotes (\n    Countrycode TEXT...

# %%
#query for foot notes 
foot_notes = pd.read_sql_query('select * from footnotes', conn)

# %%
#viewing foot note table rows and columns
foot_notes
# Out:
#        Countrycode         Seriescode    Year  \
# 0              ABW     AG.LND.FRST.K2  YR1990
# 1              ABW     AG.LND.FRST.K2  YR2000
# 2              ABW     AG.LND.FRST.K2  YR2005
# 3              ABW  BX.KLT.DINV.CD.WD  YR1987
# 4              ABW  BX.KLT.DINV.CD.WD  YR1988
# ...            ...                ...     ...
# 532410         ZWE  TX.VAL.MRCH.XD.WD  YR2006
# 532411         ZWE  TX.VAL.MRCH.XD.WD  YR2007
# 532412         ZWE  TX.VAL.MRCH.XD.WD  YR2008
# 532413         ZWE  TX.VAL.MRCH.XD.WD  YR2009
# 532414         ZWE  TX.VAL.MRCH.XD.WD  YR2010
#
#                                               Description
# 0                                           Not specified
# 1                                           Not specified
# 2                                           Not specified
# 3       Source: United Nations Conference on Trade and...
# 4       Source: United Nations Conference on Trade and...
# ...
